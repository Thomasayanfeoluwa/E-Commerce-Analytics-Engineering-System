# %% [markdown]
# ## 0. Database setup
#
# The uploaded SQL file is a PostgreSQL 13+ e-commerce database. It contains these tables:
#
# `users, addresses, categories, products, product_variants, product_images, inventory, carriers, carts, cart_items, orders, order_items, order_status_history, payments, shipments, inventory_movements`.
#
# Load the database first. Example from a terminal:
#
# ```bash
# createdb ecommerce
# psql -d ecommerce -v ON_ERROR_STOP=1 -f ecommerce.sql
# ```
#
# Then return here and connect from Python.

# %%
import pandas as pd
from sqlalchemy import create_engine, text
import os
from dotenv import load_dotenv

load_dotenv()
engine = create_engine(os.getenv("DATABASE_URL"))

# %%
def run_sql(query):
    return pd.read_sql(text(query), engine)

# Test:
run_sql("SELECT current_database(), current_user")
# Out:
#   current_database current_user
# 0        ecommerce     postgres

# %% [markdown]
# ## 0A. Schema reconnaissance — do this before solving problems
#
# Never guess a column name. Inspect the schema first.

# %%
# List columns for every table
schema_query = '''
SELECT table_name, column_name, data_type
FROM information_schema.columns
WHERE table_schema = 'public'
ORDER BY table_name, ordinal_position;
'''
run_sql(schema_query)
# Out:
#     table_name column_name                 data_type
# 0    addresses  address_id                    bigint
# 1    addresses     user_id                    bigint
# 2    addresses       label                      text
# 3    addresses       line1                      text
# 4    addresses       line2                      text
# ..         ...         ...                       ...
# 124      users       phone                      text
# 125      users   is_active                   boolean
# 126      users  created_at  timestamp with time zone
# 127      users  updated_at  timestamp with time zone
# 128      users  deleted_at  timestamp with time zone
#
# [129 rows x 3 columns]

# %% [markdown]
# # Level 1: SELECT and Filtering
#
# **Goal:** Become fluent with reading data without joins.
#
# Complete every question yourself. Put SQL in the cell directly below each question.

# %% [markdown]
# ### Level 1.1 — Return every column from `users`. Limit the output to 10 rows.

# %%
# Write your SQL here
run_sql("""
    SELECT *
    FROM users
    LIMIT 5;
""")
# Out:
#    user_id                         email  \
# 0        1     michael.allen@example.com
# 1        2      mark.hassall@example.com
# 2        3      john.peoples@example.com
# 3        4     torsten.arndt@example.com
# 4        5  tom.higginbotham@example.com
#
#                                        password_hash first_name     last_name  \
# 0  $2b$12$sampledatasampledatasuXW9dTIWkKO3RhcaCz...    Michael         Allen
# 1  $2b$12$sampledatasampledatasuXW9dTIWkKO3RhcaCz...       Mark       Hassall
# 2  $2b$12$sampledatasampledatasuXW9dTIWkKO3RhcaCz...       John       Peoples
# 3  $2b$12$sampledatasampledatasuXW9dTIWkKO3RhcaCz...    Torsten         Arndt
# 4  $2b$12$sampledatasampledatasuXW9dTIWkKO3RhcaCz...        Tom  Higginbotham
#
#      company_name           phone  is_active                       created_at  \
# 0  Customer NRZBB     030-3456789       True 2026-08-26 14:52:28.289191+00:00
# 1  Customer MLTDN    (5) 789-0123       True 2026-08-26 14:52:28.289191+00:00
# ...

# %% [markdown]
# ### Level 1.2 — Return only `user_id`, `email`, `first_name`, and `last_name`.

# %%
# Write your SQL here
run_sql("""
    SELECT user_id, email, first_name, last_name
    FROM users;
""")
# Out:
#     user_id                         email first_name     last_name
# 0         1     michael.allen@example.com    Michael         Allen
# 1         2      mark.hassall@example.com       Mark       Hassall
# 2         3      john.peoples@example.com       John       Peoples
# 3         4     torsten.arndt@example.com    Torsten         Arndt
# 4         5  tom.higginbotham@example.com        Tom  Higginbotham
# ..      ...                           ...        ...           ...
# 86       87    michael.ludwig@example.com    Michael        Ludwig
# 87       88            yan.li@example.com        Yan            Li
# 88       89   ronaldo.smithjr@example.com    Ronaldo     Smith Jr.
# 89       90  katarina.larsson@example.com   Katarina       Larsson
# 90       91        steve.conn@example.com      Steve          Conn
#
# [91 rows x 4 columns]

# %% [markdown]
# ### Level 1.3 — Find all active users.

# %%
# Write your SQL here
run_sql("""
    SELECT first_name || ' ' || last_name AS "Customer Name",
        is_active AS "Active User"
    FROM users
    WHERE is_active IS TRUE
    LIMIT 15;
""")
# Out:
#            Customer Name  Active User
# 0          Michael Allen         True
# 1           Mark Hassall         True
# 2           John Peoples         True
# 3          Torsten Arndt         True
# 4       Tom Higginbotham         True
# 5          Carole Poland         True
# 6        Dushyant Bansal         True
# 7           Julia Ilyina         True
# 8       Amritansh Raghav         True
# 9   Pilar Colome Bassols         True
# 10           David Jaffe         True
# 11              Mike Ray         True
# 12       Almudena Benito         True
# 13         Jacek Jelitto         True
# 14      Shawn Richardson         True

# %% [markdown]
# ### Level 1.4 — Find all inactive users.

# %%
# Write your SQL here
run_sql("""
    SELECT first_name || ' ' || last_name AS "Customer Name",
        is_active AS "Active User"
    FROM users
    WHERE is_active = False;
""")
# Out:
# Empty DataFrame
# Columns: [Customer Name, Active User]
# Index: []

# %% [markdown]
# ### Level 1.5 — Find users whose country code in `addresses` is `US`.

# %%
run_sql("""
    SELECT *
    FROM addresses
    LIMIT 3;
""")
# Out:
#    address_id  user_id    label                           line1 line2  \
# 0           1        1  Primary                 Obere Str. 0123  None
# 1           2        2  Primary  Avda. de la ConstituciÃ³n 5678  None
# 2           3        3  Primary                 Mataderos  7890  None
#
#            city region postal_code country_code  is_default_shipping  \
# 0        Berlin   None       10092           DE                 True
# 1  MÃ©xico D.F.   None       10077           MX                 True
# 2  MÃ©xico D.F.   None       10097           MX                 True
#
#    is_default_billing                       created_at  \
# 0                True 2026-08-26 14:52:28.289191+00:00
# 1                True 2026-08-26 14:52:28.289191+00:00
# 2                True 2026-08-26 14:52:28.289191+00:00
#
#                         updated_at
# 0 2026-08-26 14:52:28.289191+00:00
# 1 2026-08-26 14:52:28.289191+00:00
# 2 2026-08-26 14:52:28.289191+00:00

# %%
# Write your SQL here
run_sql("""
    SELECT user_id, country_code
    FROM addresses
    WHERE country_code = 'US'
    LIMIT 10;
""")
# Out:
#    user_id country_code
# 0       32           US
# 1       36           US
# 2       43           US
# 3       45           US
# 4       48           US
# 5       55           US
# 6       65           US
# 7       71           US
# 8       75           US
# 9       77           US

# %% [markdown]
# ### Level 1.6 — Find products that are not active.

# %%
run_sql("""
    SELECT *
    FROM products
    LIMIT 3;
""")
# Out:
#    product_id  category_id           name           slug  \
# 0           1            1  Product HHYDP  product-hhydp
# 1           2            1  Product RECZE  product-recze
# 2           3            2  Product IMEHJ  product-imehj
#
#                              description attributes  is_active  \
# 0  Sample description for Product HHYDP.         {}       True
# 1  Sample description for Product RECZE.         {}       True
# 2  Sample description for Product IMEHJ.         {}       True
#
#                                              search  \
# 0  'descript':4 'hhydp':2,7 'product':1,6 'sampl':3
# 1   'descript':4 'product':1,6 'recz':2,7 'sampl':3
# 2  'descript':4 'imehj':2,7 'product':1,6 'sampl':3
#
#                         created_at                       updated_at deleted_at
# 0 2026-08-26 14:52:28.289191+00:00 2026-08-26 14:52:28.289191+00:00       None
# 1 2026-08-26 14:52:28.289191+00:00 2026-08-26 14:52:28.289191+00:00       None
# ...

# %%
# Write your SQL here
run_sql("""
    SELECT product_id, is_active
    FROM products
    WHERE is_active IS FALSE;
""")
# Out:
#    product_id  is_active
# 0           5      False
# 1           9      False
# 2          17      False
# 3          24      False
# 4          28      False
# 5          29      False
# 6          42      False
# 7          53      False

# %% [markdown]
# ### Level 1.7 — Return products whose name starts with `Product A`.

# %%
# Write your SQL here
run_sql("""
    SELECT product_id, name
    FROM products
    WHERE name LIKE 'Product A%';
""")
# Out:
#    product_id           name
# 0           9  Product AOZBW
# 1          33  Product ASTMN
# 2          45  Product AQOKR
# 3          51  Product APITJ
# 4          58  Product ACRVI

# %% [markdown]
# ### Level 1.8 — Return orders with status `cancelled`.

# %%
run_sql("""
    SELECT *
    FROM orders
    LIMIT 3;
""")
# Out:
#    order_id  user_id order_number     status currency  subtotal  \
# 0     10248       85    ORD-10248  delivered      USD     440.0
# 1     10249       79    ORD-10249  delivered      USD    1863.4
# 2     10250       34    ORD-10250  delivered      USD    1813.0
#
#    discount_total  shipping_total  grand_total          ship_name  \
# 0             0.0           32.38       472.38       Ship to 85-B
# 1             0.0           11.61      1875.01       Ship to 79-C
# 2           260.4           65.83      1618.43  Destination SCQXA
#
#              ship_line1       ship_city ship_region ship_postal_code  \
# 0  6789 rue de l'Abbaye           Reims        None            10345
# 1       Luisenstr. 9012        MÃ¼nster        None            10328
# 2    Rua do PaÃ§o, 7890  Rio de Janeiro          RJ            10195
#
#   ship_country_code                ordered_at  \
# 0                FR 2006-07-04 00:00:00+00:00
# 1                DE 2006-07-05 00:00:00+00:00
# ...

# %%
# Write your SQL here
run_sql("""
    SELECT order_id, status
    FROM orders
    WHERE status = 'cancelled';
""")
# Out:
#    order_id     status
# 0     11077  cancelled

# %% [markdown]
# ### Level 1.9 — Return orders whose total is greater than 1000.

# %%
# Write your SQL here
run_sql("""
    SELECT grand_total AS "Total Orders > 1000"
    FROM orders
    WHERE grand_total > 1000
    LIMIT 10;
""")
# Out:
#    Total Orders > 1000
# 0              1875.01
# 1              1618.43
# 2              3649.20
# 3              1502.97
# 4              2638.83
# 5              1201.81
# 6              1755.39
# 7              1559.74
# 8              2019.86
# 9              1231.28

# %% [markdown]
# ### Level 1.10 — Return orders created between two dates of your choice using `BETWEEN`.

# %%
# Write your SQL here
run_sql("""
    SELECT order_id, ordered_at AS "Ordered Dates"
    FROM orders
    WHERE ordered_at BETWEEN '2008-05-06' AND '2026-08-26'
""")

# run_sql("""
#     SELECT order_id, ordered_at AS "Ordered Dates"
#     FROM orders
#     WHERE ordered_at BETWEEN '2008-05-06' AND '2026-08-26'
# """)
# Out:
#    order_id             Ordered Dates
# 0     11074 2008-05-06 00:00:00+00:00
# 1     11075 2008-05-06 00:00:00+00:00
# 2     11076 2008-05-06 00:00:00+00:00
# 3     11077 2008-05-06 00:00:00+00:00

# %%
run_sql("""
    SELECT order_id,
           ordered_at,
           created_at,
           updated_at
    FROM orders
    ORDER BY order_id DESC
    LIMIT 10
""")
# Out:
#    order_id                ordered_at                       created_at  \
# 0     11077 2008-05-06 00:00:00+00:00 2026-08-26 14:52:28.289191+00:00
# 1     11076 2008-05-06 00:00:00+00:00 2026-08-26 14:52:28.289191+00:00
# 2     11075 2008-05-06 00:00:00+00:00 2026-08-26 14:52:28.289191+00:00
# 3     11074 2008-05-06 00:00:00+00:00 2026-08-26 14:52:28.289191+00:00
# 4     11073 2008-05-05 00:00:00+00:00 2026-08-26 14:52:28.289191+00:00
# 5     11072 2008-05-05 00:00:00+00:00 2026-08-26 14:52:28.289191+00:00
# 6     11071 2008-05-05 00:00:00+00:00 2026-08-26 14:52:28.289191+00:00
# 7     11070 2008-05-05 00:00:00+00:00 2026-08-26 14:52:28.289191+00:00
# 8     11069 2008-05-04 00:00:00+00:00 2026-08-26 14:52:28.289191+00:00
# 9     11068 2008-05-04 00:00:00+00:00 2026-08-26 14:52:28.289191+00:00
#
#                         updated_at
# 0 2026-08-26 14:52:28.289191+00:00
# 1 2026-08-26 14:52:28.289191+00:00
# 2 2026-08-26 14:52:28.289191+00:00
# 3 2026-08-26 14:52:28.289191+00:00
# ...

# %% [markdown]
# ### Level 1.11 — Find rows where an optional field is NULL.

# %%
# Write your SQL here
run_sql("""
    SELECT address_id, user_id, city, region
    FROM addresses
    WHERE region IS NULL;
""")
# Out:
#     address_id  user_id            city region
# 0            1        1          Berlin   None
# 1            2        2    MÃ©xico D.F.   None
# 2            3        3    MÃ©xico D.F.   None
# 3            4        4          London   None
# 4            5        5          LuleÃ¥   None
# 5            6        6        Mannheim   None
# 6            7        7      Strasbourg   None
# 7            8        8          Madrid   None
# 8            9        9       Marseille   None
# 9           11       11          London   None
# 10          12       12    Buenos Aires   None
# 11          13       13    MÃ©xico D.F.   None
# 12          14       14            Bern   None
# 13          16       16          London   None
# 14          17       17          Aachen   None
# 15          18       18          Nantes   None
# 16          19       19          London   None
# 17          20       20            Graz   None
# 18          22       22          Madrid   None
# ...

# %% [markdown]
# ### Level 1.12 — Find rows where an optional field is NOT NULL.

# %%
# Write your SQL here
run_sql("""
    SELECT order_id,
        user_id, ship_line1,
        ship_city, ship_region
    FROM orders
    WHERE ship_region IS NOT NULL
    LIMIT 10;
""")
# Out:
#    order_id  user_id                                   ship_line1  \
# 0     10250       34                           Rua do PaÃ§o, 7890
# 1     10253       34                           Rua do PaÃ§o, 8901
# 2     10256       88                         Rua do Mercado, 5678
# 3     10257       35  Carrera1234 con Ave. Carlos Soublette #8-35
# 4     10261       61                    Rua da Panificadora, 6789
# 5     10262       65                              8901 Milton Dr.
# 6     10268       33              5Âª Ave. Los Palos Grandes 5678
# 7     10269       89                          8901 - 12th Ave. S.
# 8     10271       75                                P.O. Box 7890
# 9     10272       65                              7890 Milton Dr.
#
#         ship_city ship_region
# 0  Rio de Janeiro          RJ
# 1  Rio de Janeiro          RJ
# 2         Resende          SP
# 3  San CristÃ³bal    TÃ¡chira
# 4  Rio de Janeiro          RJ
# 5     Albuquerque          NM
# ...

# %% [markdown]
# ### Level 1.13 — Sort products alphabetically by name.

# %%
# Write your SQL here
run_sql("""
    SELECT product_id, name, description
    FROM products
    ORDER BY name
""")
# Out:
#     product_id           name                            description
# 0           58  Product ACRVI  Sample description for Product ACRVI.
# 1            9  Product AOZBW  Sample description for Product AOZBW.
# 2           51  Product APITJ  Sample description for Product APITJ.
# 3           45  Product AQOKR  Sample description for Product AQOKR.
# 4           33  Product ASTMN  Sample description for Product ASTMN.
# ..         ...            ...                                    ...
# 72          61  Product XYZPE  Sample description for Product XYZPE.
# 73          10  Product YHXGE  Sample description for Product YHXGE.
# 74          55  Product YYWRT  Sample description for Product YYWRT.
# 75          40  Product YZIXQ  Sample description for Product YZIXQ.
# 76          43  Product ZZZHR  Sample description for Product ZZZHR.
#
# [77 rows x 3 columns]

# %% [markdown]
# ### Level 1.14 — Return the 10 highest-value orders.

# %%
# Write your SQL here
run_sql("""
    SELECT order_id, order_number,
        grand_total AS "Highest Value Orders"
    FROM orders
    ORDER BY grand_total DESC
    LIMIT 10;
""")
# Out:
#    order_id order_number  Highest Value Orders
# 0     10865    ORD-10865              16735.64
# 1     10981    ORD-10981              16003.37
# 2     11030    ORD-11030              13445.80
# 3     10889    ORD-10889              11660.61
# 4     10897    ORD-10897              11438.78
# 5     10817    ORD-10817              11258.92
# 6     10417    ORD-10417              11258.69
# 7     10479    ORD-10479              11204.55
# 8     10540    ORD-10540              11199.34
# 9     10691    ORD-10691              10974.85

# %% [markdown]
# ### Level 1.15 — Return the 10 lowest-value orders.

# %%
# Write your SQL here
run_sql("""
    SELECT order_id, order_number,
        grand_total AS "Lowest Value Orders"
    FROM orders
    ORDER BY grand_total 
    LIMIT 10;
""")
# Out:
#    order_id order_number  Lowest Value Orders
# 0     10782    ORD-10782                13.60
# 1     10807    ORD-10807                19.76
# 2     10586    ORD-10586                24.28
# 3     10767    ORD-10767                29.59
# 4     10898    ORD-10898                31.27
# 5     10900    ORD-10900                35.41
# 6     10883    ORD-10883                36.53
# 7     11051    ORD-11051                38.79
# 8     10674    ORD-10674                45.90
# 9     11057    ORD-11057                49.13

# %% [markdown]
# # Level 2: Aggregation and GROUP BY
#
# **Goal:** Calculate counts, sums, averages, minimums and maximums correctly.
#
# Complete every question yourself. Put SQL in the cell directly below each question.

# %% [markdown]
# ### Level 2.1 — Count the number of users.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 2.2 — Count active and inactive users separately.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 2.3 — Count products in each category.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 2.4 — Find the average order total.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 2.5 — Find the minimum and maximum order total.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 2.6 — Calculate total gross revenue from all orders.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 2.7 — Calculate total order value by order status.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 2.8 — Find the top 10 customers by number of orders.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 2.9 — Find the top 10 customers by total spending.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 2.10 — Calculate the average quantity per order item.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 2.11 — Calculate total units sold for each product name.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 2.12 — Find categories with more than 5 products using `HAVING`.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 2.13 — Find order statuses whose average order total exceeds a threshold you choose.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 2.14 — Calculate total discount by order.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 2.15 — Calculate each order's total quantity purchased.

# %%
# Write your SQL here

# %% [markdown]
# # Level 3: CASE, NULL and Data Cleaning
#
# **Goal:** Use conditional logic and safely handle missing values.
#
# Complete every question yourself. Put SQL in the cell directly below each question.

# %% [markdown]
# ### Level 3.1 — Classify orders as `small`, `medium`, or `large` using thresholds you define.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 3.2 — Replace NULL region values with `Unknown` using `COALESCE`.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 3.3 — Count addresses with and without a region.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 3.4 — Create a boolean/label showing whether each product is active.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 3.5 — Create a customer name using first name and last name.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 3.6 — Classify products as `active` or `inactive` with CASE.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 3.7 — Calculate net line value from `unit_price`, `qty`, and `discount` and verify your formula against the data meaning.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 3.8 — Identify suspicious order rows where a monetary value is negative or NULL.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 3.9 — Count cancelled, pending, processing and other statuses using conditional aggregation.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 3.10 — Create a data-quality query that checks whether order totals are consistent with order items for a sample of orders.

# %%
# Write your SQL here

# %% [markdown]
# # Level 4: INNER and OUTER JOINS
#
# **Goal:** Understand table relationships and prevent accidental duplication.
#
# Complete every question yourself. Put SQL in the cell directly below each question.

# %% [markdown]
# ### Level 4.1 — Join users to addresses and show each user's address details.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 4.2 — Join products to categories and show product name with category name.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 4.3 — Join orders to users and show customer information for each order.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 4.4 — Join orders to order_items and show each order with its purchased items.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 4.5 — Join order_items to product_variants where the relationship is available.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 4.6 — Find users who have no orders using a LEFT JOIN.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 4.7 — Find products that have never appeared in order_items.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 4.8 — Find categories that have no products.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 4.9 — Find orders that have no shipment.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 4.10 — Find orders that have no payment.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 4.11 — Find users and their total number of orders, including users with zero orders.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 4.12 — Find products and total units sold, including products with zero sales where the schema relationship allows it.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 4.13 — Build one joined view showing order ID, customer, order status, total, payment information and shipment information.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 4.14 — Explain in a markdown cell why a one-to-many join can increase row counts.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 4.15 — Create a query that detects duplicate multiplication caused by joining multiple one-to-many tables.

# %%
# Write your SQL here

# %% [markdown]
# # Level 5: Subqueries and Correlated Subqueries
#
# **Goal:** Use subqueries when they make the question clearer.
#
# Complete every question yourself. Put SQL in the cell directly below each question.

# %% [markdown]
# ### Level 5.1 — Find orders above the overall average order total.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 5.2 — Find customers whose total spending is above the average customer spending.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 5.3 — Find products whose total units sold is above the average units sold per product.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 5.4 — Find the customer or customers with the maximum total spending.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 5.5 — Find orders containing at least one line item above a price threshold.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 5.6 — Use `EXISTS` to find users who have placed at least one order.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 5.7 — Use `NOT EXISTS` to find products never ordered.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 5.8 — Find each category's most expensive product using a subquery or correlated subquery.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 5.9 — Find orders larger than that customer's average order value.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 5.10 — Find customers whose latest order is more recent than a date you choose.

# %%
# Write your SQL here

# %% [markdown]
# # Level 6: CTEs
#
# **Goal:** Break complex analysis into named, testable steps.
#
# Complete every question yourself. Put SQL in the cell directly below each question.

# %% [markdown]
# ### Level 6.1 — Create a CTE that calculates total spending per customer, then return the top 10.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 6.2 — Create a CTE for order totals derived from order_items and compare it with stored order totals.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 6.3 — Create CTEs for customer order counts and customer spending, then combine them.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 6.4 — Create a CTE for monthly revenue and calculate month-over-month change.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 6.5 — Create a CTE that finds each customer's first and latest order.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 6.6 — Create a CTE that identifies customers with more than one order and calculates their repeat rate.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 6.7 — Create a multi-step CTE: line revenue → order revenue → customer revenue.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 6.8 — Create a CTE for cancelled orders and calculate their share of all orders.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 6.9 — Create a CTE for product sales and return the top product in every category.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 6.10 — Refactor one earlier difficult query into readable CTEs with meaningful names.

# %%
# Write your SQL here

# %% [markdown]
# # Level 7: Window Functions
#
# **Goal:** Perform ranking and analytical calculations without collapsing rows.
#
# Complete every question yourself. Put SQL in the cell directly below each question.

# %% [markdown]
# ### Level 7.1 — Rank customers by total spending using `RANK()`.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 7.2 — Rank customers by total spending using `DENSE_RANK()` and compare the result.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 7.3 — Return the top 3 customers by spending.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 7.4 — Return the top 3 products within each category by units sold.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 7.5 — Calculate a running total of revenue ordered by date.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 7.6 — Calculate each customer's running cumulative spending.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 7.7 — Use `LAG()` to compare each month's revenue with the previous month.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 7.8 — Calculate percentage change from the previous month, handling division by zero.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 7.9 — Use `ROW_NUMBER()` to identify each customer's first order.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 7.10 — Use `ROW_NUMBER()` to identify each customer's latest order.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 7.11 — Calculate each order's percentage contribution to its customer's total spending.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 7.12 — Calculate the difference between each order and that customer's average order value.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 7.13 — Find each category's highest-selling product.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 7.14 — Create customer spending percentiles using `NTILE(4)`.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 7.15 — Use a window function to flag unusually large orders relative to the customer's own history.

# %%
# Write your SQL here

# %% [markdown]
# # Level 8: Dates, Time Series and Business Analytics
#
# **Goal:** Extract useful business signals without leaking future information.
#
# Complete every question yourself. Put SQL in the cell directly below each question.

# %% [markdown]
# ### Level 8.1 — Calculate daily revenue.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 8.2 — Calculate weekly revenue.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 8.3 — Calculate monthly revenue.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 8.4 — Calculate monthly order count.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 8.5 — Calculate average order value by month.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 8.6 — Calculate monthly active customers.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 8.7 — Calculate new customers by the month of their first order.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 8.8 — Calculate returning customers by month.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 8.9 — Calculate days between each customer's consecutive orders using `LAG()`.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 8.10 — Calculate customer recency: days since each customer's latest order.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 8.11 — Build an RFM-style table: recency, frequency, monetary value.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 8.12 — Calculate revenue by country using address/order data carefully and explain the business assumption.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 8.13 — Find the best and worst revenue month.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 8.14 — Calculate a 3-period rolling average of revenue.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 8.15 — Create a cohort analysis based on each customer's first order month.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 8.16 — Identify customers whose spending trend is declining compared with their earlier history.

# %%
# Write your SQL here

# %% [markdown]
# # Level 9: Complex Business Problems
#
# **Goal:** Combine SQL techniques to answer realistic analytical questions.
#
# Complete every question yourself. Put SQL in the cell directly below each question.

# %% [markdown]
# ### Level 9.1 — Build a customer 360 query: customer identity, order count, total spend, average order value, first order, latest order, recency and status summary.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 9.2 — Build a product performance table: category, units sold, revenue, average discount and number of orders containing the product.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 9.3 — Find the Pareto concentration: what percentage of revenue comes from the top 20% of customers?

# %%
# Write your SQL here

# %% [markdown]
# ### Level 9.4 — Identify customers at risk of inactivity using a rule based on their historical ordering gap.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 9.5 — Find products with high sales volume but unusually high average discount.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 9.6 — Find products with inventory but no sales.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 9.7 — Find products with strong sales and low remaining inventory.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 9.8 — Find orders whose stored total differs materially from the sum implied by order_items.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 9.9 — Build a cancellation dashboard query by month and customer segment.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 9.10 — Build a payment reconciliation query: orders versus payments, showing possible mismatches.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 9.11 — Build a shipment delay investigation using order and shipment timestamps where available.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 9.12 — Identify repeat customers and calculate repeat-purchase rate.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 9.13 — Build a query for top customer-product combinations.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 9.14 — Find market-basket style product pairs frequently purchased in the same order using a self-join.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 9.15 — Design a SQL feature table that could be exported for a churn prediction model, ensuring every feature uses only information available before the prediction time.

# %%
# Write your SQL here

# %% [markdown]
# # Level 10: PostgreSQL Engineering, Performance and Transactions
#
# **Goal:** Move beyond writing correct SQL into writing and diagnosing database work.
#
# Complete every question yourself. Put SQL in the cell directly below each question.

# %% [markdown]
# ### Level 10.1 — Use `EXPLAIN` on a simple filter query and describe the plan.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 10.2 — Use `EXPLAIN ANALYZE` on a realistic aggregation query.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 10.3 — Identify a column frequently used in joins or filters and propose an index. Do not create it until you explain why.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 10.4 — Create the proposed index in a test environment and compare query plans before and after.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 10.5 — Write a transaction that inserts a new cart item and updates related state, then explain rollback behavior.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 10.6 — Demonstrate `BEGIN`, `COMMIT`, and `ROLLBACK` safely on test data.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 10.7 — Inspect existing indexes using PostgreSQL system catalogs.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 10.8 — Write a query to identify the largest tables conceptually/physically using PostgreSQL metadata.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 10.9 — Use `EXPLAIN (ANALYZE, BUFFERS)` if your environment permits it and interpret the result.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 10.10 — Write a short markdown explanation: when an index can hurt performance.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 10.11 — Identify one query in this notebook that should remain simple rather than being over-engineered.

# %%
# Write your SQL here

# %% [markdown]
# ### Level 10.12 — Create one reusable SQL view for an analytics question and justify its columns.

# %%
# Write your SQL here

# %% [markdown]
# # Capstone: SQL Readiness Test
#
# Do these **without notes**.
#
# 1. Explain the schema and key relationships.
# 2. Write 10 non-trivial SQL queries from memory.
# 3. Use joins, CTEs and window functions in at least one query.
# 4. Find and explain one data-quality issue.
# 5. Use `EXPLAIN` on one query.
# 6. Export one ML-ready feature table.
# 7. Explain how temporal leakage could occur in that feature table.
#
# Your programme's SQL gate is the ability to answer non-trivial SQL questions without copying solutions and explain the schema. fileciteturn2file1L246-L256

# %% [markdown]
# # Personal mistake log
#
# After each session, record:
#
# - Question number:
# - What I tried:
# - Error message/result:
# - Root cause:
# - Exact concept I was missing:
# - Correct approach:
# - Can I reproduce it tomorrow without notes?
#
# Debug systematically: read the complete error, locate the failing line/query, compare expected versus actual behavior, reproduce the smallest failing case, inspect values/types, form one hypothesis, change one thing, rerun, and record the root cause. fileciteturn2file6L664-L676

# %%
mistake_log = pd.DataFrame(columns=[
    "date", "level", "question", "what_failed",
    "root_cause", "concept_to_review", "fixed", "notes"
])
mistake_log
# Out:
# Empty DataFrame
# Columns: [date, level, question, what_failed, root_cause, concept_to_review, fixed, notes]
# Index: []
